# %%
import pandas as pd

# %%
pd.read_csv('../../data/raw/mlb_elo.csv', delimiter=',')
# Out:
#               date  season  neutral playoff team1 team2     elo1_pre  \
# 0       10/27/2020    2020        1       w   LAD   TBD  1607.757915
# 1       10/25/2020    2020        1       w   TBD   LAD  1566.449752
# 2       10/24/2020    2020        1       w   TBD   LAD  1563.862158
# 3       10/23/2020    2020        1       w   TBD   LAD  1567.099442
# 4       10/21/2020    2020        1       w   LAD   TBD  1608.352409
# ...            ...     ...      ...     ...   ...   ...          ...
# 220956  1871-05-09    1871        0     NaN   TRO   ATL  1450.000000
# 220957  1871-05-08    1871        0     NaN   CHC   CL1  1450.000000
# 220958  1871-05-06    1871        0     NaN   RC1   CL1  1450.000000
# 220959  1871-05-05    1871        0     NaN   WS3   ATL  1450.000000
# 220960  1871-05-04    1871        0     NaN   FW1   CL1  1450.000000
#
#            elo2_pre  elo_prob1  elo_prob2  ...  pitcher1_rgs  pitcher2_rgs  \
# ...
